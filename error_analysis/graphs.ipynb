# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

file = Path().absolute()
df = pd.read_csv(file / "csvs" / "variation_in_K.csv")

# %%
plt.figure(figsize=(8, 5))

for matrix, group in df.groupby("matrix"):
    plt.plot(
        group["K"],
        group["frob_norm"],
        marker="o",
        label=matrix
    )

plt.xlabel("K")
plt.ylabel("Frobenius Norm")
plt.title("Subspace Estimation Error vs K")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_n = pd.read_csv(file / "csvs" / "variation_in_n.csv")

plt.figure(figsize=(8, 5))

for matrix, group in df_n.groupby("matrix"):
    plt.plot(
        group["n"],
        group["frob_norm"],
        marker="o",
        label=matrix
    )

plt.xlabel("n")
plt.ylabel("Frobenius Norm")
plt.title("Subspace Estimation Error vs n")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_ni = pd.read_csv(file / "csvs" / "variation_in_n_irlb.csv")
df_ni = df_ni.sort_values(by="n")

plt.figure(figsize=(8, 5))

for matrix, group in df_ni.groupby("matrix"):
    plt.plot(
        group["n"],
        group["frob_norm"],
        marker="o",
        label=matrix
    )

plt.xlabel("n")
plt.ylabel("Frobenius Norm")
plt.title("(IRLB) Subspace Estimation Error vs n")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_r = pd.read_csv(file / "csvs" / "variation_in_r.csv")

plt.figure(figsize=(8, 5))

plt.figure(figsize=(8, 5))

for matrix, group in df_r.groupby("matrix"):
    plt.plot(
        group["r"],
        group["frob_norm"],
        marker="o",
        label=matrix
    )

plt.xlabel("r")
plt.ylabel("Frobenius Norm")
plt.title("Subspace Estimation Error vs r")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_r = pd.read_csv(file / "csvs" / "variation_in_r_irlb.csv")

df_r = df_r.sort_values("r")

plt.figure(figsize=(8, 5))

plt.figure(figsize=(8, 5))

for matrix, group in df_r.groupby("matrix"):
    plt.plot(
        group["r"],
        group["frob_norm"],
        marker="o",
        label=matrix
    )

plt.xlabel("r")
plt.ylabel("Frobenius Norm")
plt.title("(IRLB) Subspace Estimation Error vs r")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
